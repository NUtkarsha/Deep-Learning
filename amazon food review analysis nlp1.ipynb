# %% [markdown]
# <p style = "font-size:30px; color: #6610f2 "><strong> Data Description</strong></p>

# %% [markdown]
# - This dataset consists of reviews of  foods from amazon. The data span
#  a period of more than 10 years, including all ~500,000 reviews up to
#  October 2012. Reviews include product and user information, ratings, and
#  a plain text review. It also includes reviews from all other Amazon
#  categories.
#
#
# - **The Amazon Food Reviews dataset consists of reviews of  foods from Amazon.**
#     - Number of reviews: 568,454
#     - Number of users: 256,059
#     - Number of products: 74,258
#     - Timespan: Oct 1999 - Oct 2012
#     - Number of Attributes/Columns in data: 10
#
#
# - **Attribute Information:**
#     - Id
#     - ProductId - unique identifier for the product
#     - UserId - unqiue identifier for the user
#     - ProfileName
#     - HelpfulnessNumerator - number of users who found the review helpful
#     - HelpfulnessDenominator - number of users who indicated whether they found the review helpful or not
#     - Score - rating between 1 and 5
#     - Time - timestamp for the review
#     - Summary - brief summary of the review
#     - Text - text of the review

# %% [raw]
# <p style = "font-size:30px; color: #007580  "><strong> Data Description</strong></p>

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

import nltk
from nltk.corpus import stopwords
from nltk import stem
import string

# wordcloud library
from wordcloud import WordCloud, STOPWORDS
from nltk.corpus import stopwords

#regular expression library
import re

# Importing machine learning libraries
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# <p style = "font-size:30px; color: #007580  "><strong> Creat Dataframe</strong></p>

# %% [markdown]
# - **The data we have is in the form of text file so we need to convert the data from text file into a dataframe**

# %%
# read the text file and store the data in variable
def load_doc(data):
    file = open(data, 'r')
    text = file.read()
    file.close()
    return text

# %%
# store the data in list
l=[]
for i in range(1,10001):
    filename = 'data/review_{}.txt'.format(i)
    text=load_doc(filename)
    l.append(text)

# %%
# store different data in different lists
l1=[]
for i in l:
    a=i.split('\n')
    l1.append(a)
pid=[]
uid=[]
profile_name=[]
HelpfulnessNumerator=[]
HelpfulnessDenominator=[]
Score=[]
Time=[]
ReviewSummary=[]
ReviewText=[]
for i in range(0,len(l1)):
    pid.append(l1[i][0])
    uid.append(l1[i][1])
    profile_name.append(l1[i][2])
    HelpfulnessNumerator.append(l1[i][3])
    HelpfulnessDenominator.append(l1[i][4])
    Score.append(l1[i][5])
    Time.append(l1[i][6])
    ReviewSummary.append(l1[i][7])
    ReviewText.append(l1[i][8])

# %%
# Create a dataframe
df=pd.DataFrame({'Product_Id':pid,'User_Id':uid,'profile_name':profile_name,'Helpfulness_Numerator':HelpfulnessNumerator,'Helpfulness_Denominator':HelpfulnessDenominator,'Score':Score,'Time':Time,'Review_Summary':ReviewSummary,'Review_Text':ReviewText})

# %%
df
# Out:
#                  Product_Id                 User_Id  \
# 0     ProductId: B001E4KFG0  UserId: A3SGXH7AUHU8GW
# 1     ProductId: B00813GRG4  UserId: A1D87F6ZCVE5NK
# 2     ProductId: B000LQOCH0   UserId: ABXLMWJIXXAIN
# 3     ProductId: B000UA0QIQ  UserId: A395BORC6FGVXV
# 4     ProductId: B006K2ZZ7K  UserId: A1UQRSCLF8GW1T
# ...                     ...                     ...
# 9995  ProductId: B000P41A28  UserId: A3A63RACXR1XIL
# 9996  ProductId: B000P41A28    UserId: A5VVRGL8JA7R
# 9997  ProductId: B000P41A28  UserId: A2TGDTJ8YCU6PD
# 9998  ProductId: B000P41A28   UserId: AUV4GIZZE693O
# 9999  ProductId: B000P41A28   UserId: A82WIMR4RSVLI
#
#                                       profile_name     Helpfulness_Numerator  \
# 0                          ProfileName: delmartian   HelpfulnessNumerator: 1
# 1                              ProfileName: dll pa   HelpfulnessNumerator: 0
# 2     ProfileName: Natalia Corres "Natalia Corres"   HelpfulnessNumerator: 1
# 3                                ProfileName: Karl   HelpfulnessNumerator: 3
# 4       ProfileName: Michael D. Bigham "M. Wassir"   HelpfulnessNumerator: 0
# ...                                            ...                       ...
# 9995            ProfileName: A. Boodhoo "deaddodo"  HelpfulnessNumerator: 10
# 9996                             ProfileName: Adam   HelpfulnessNumerator: 2
# 9997                          ProfileName: geena77   HelpfulnessNumerator: 0
# 9998              ProfileName: Susan Coe "sueysis"   HelpfulnessNumerator: 1
# 9999                       ProfileName: Emrose mom   HelpfulnessNumerator: 0
#
#          Helpfulness_Denominator     Score              Time  \
# 0      HelpfulnessDenominator: 1  Score: 5  Time: 1303862400
# 1      HelpfulnessDenominator: 0  Score: 1  Time: 1346976000
# 2      HelpfulnessDenominator: 1  Score: 4  Time: 1219017600
# 3      HelpfulnessDenominator: 3  Score: 2  Time: 1307923200
# 4      HelpfulnessDenominator: 0  Score: 5  Time: 1350777600
# ...                          ...       ...               ...
# 9995  HelpfulnessDenominator: 15  Score: 1  Time: 1204502400
# 9996   HelpfulnessDenominator: 3  Score: 5  Time: 1306368000
# 9997   HelpfulnessDenominator: 0  Score: 5  Time: 1347494400
# 9998   HelpfulnessDenominator: 2  Score: 5  Time: 1203638400
# 9999   HelpfulnessDenominator: 1  Score: 4  Time: 1337472000
#
#                                        Review_Summary  \
# 0                ReviewSummary: Good Quality Dog Food
# 1                    ReviewSummary: Not as Advertised
# 2                ReviewSummary: "Delight" says it all
# 3                       ReviewSummary: Cough Medicine
# 4                          ReviewSummary: Great taffy
# ...                                               ...
# 9995                      ReviewSummary: constipation
# 9996  ReviewSummary: Constipation Not A Problem if...
# 9997                ReviewSummary: Love this formula!
# 9998                   ReviewSummary: very convenient
# 9999        ReviewSummary: The best weve tried so far
#
#                                             Review_Text
# 0     ReviewText: I have bought several of the Vital...
# 1     ReviewText: Product arrived labeled as Jumbo S...
# 2     ReviewText: This is a confection that has been...
# 3     ReviewText: If you are looking for the secret ...
# 4     ReviewText: Great taffy at a great price.  The...
# ...                                                 ...
# 9995  ReviewText: we switched from the advance simil...
# 9996  ReviewText: Like the bad reviews say, the orga...
# 9997  ReviewText: I wanted to solely breastfeed but ...
# 9998  ReviewText: i love the fact that i can get thi...
# 9999  ReviewText: We have a 7 week old... He had gas...
#
# [10000 rows x 9 columns]

# %% [markdown]
# - **we can see that there are some impurities present in our dataset, we need to remove that impurities**

# %%
# remove unnecessary values
df['Review_Text']=df['Review_Text'].replace({'ReviewText:':''},regex=True)
df['Review_Summary']=df['Review_Summary'].replace({'ReviewSummary:':''},regex=True)
df['Product_Id']=df['Product_Id'].replace({'ProductId:':''},regex=True)
df['User_Id']=df['User_Id'].replace({'UserId:':''},regex=True)
df['profile_name']=df['profile_name'].replace({'ProfileName:':''},regex=True)
df['Helpfulness_Numerator']=df['Helpfulness_Numerator'].replace({'HelpfulnessNumerator:':''},regex=True)
df['Helpfulness_Denominator']=df['Helpfulness_Denominator'].replace({'HelpfulnessDenominator:':''},regex=True)
df['Score']=df['Score'].replace({'Score:':''},regex=True)
df['Time']=df['Time'].replace({'Time:':''},regex=True)

# %%
df.head()
# Out:
#     Product_Id          User_Id                      profile_name  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#   Helpfulness_Numerator Helpfulness_Denominator Score         Time  \
# 0                     1                       1     5   1303862400
# 1                     0                       0     1   1346976000
# 2                     1                       1     4   1219017600
# 3                     3                       3     2   1307923200
# 4                     0                       0     5   1350777600
#
#            Review_Summary                                        Review_Text
# 0   Good Quality Dog Food   I have bought several of the Vitality canned ...
# 1       Not as Advertised   Product arrived labeled as Jumbo Salted Peanu...
# 2   "Delight" says it all   This is a confection that has been around a f...
# 3          Cough Medicine   If you are looking for the secret ingredient ...
# 4             Great taffy   Great taffy at a great price.  There was a wi...

# %% [markdown]
# - **The dataset seems clean**

# %%
df.to_csv('review_dataset1.csv',index=False)

# %%
df = pd.read_csv('review_dataset1.csv')

# %%
df_copy = df.copy()

# %%
# check the shape 
df.shape
# Out:
# (10000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product_Id               10000 non-null  object
#  1   User_Id                  10000 non-null  object
#  2   profile_name             10000 non-null  object
#  3   Helpfulness_Numerator    10000 non-null  int64
#  4   Helpfulness_Denominator  10000 non-null  int64
#  5   Score                    10000 non-null  int64
#  6   Time                     10000 non-null  int64
#  7   Review_Summary           10000 non-null  object
#  8   Review_Text              10000 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 703.2+ KB

# %%
df.isna().sum()
# Out:
# Product_Id                 0
# User_Id                    0
# profile_name               0
# Helpfulness_Numerator      0
# Helpfulness_Denominator    0
# Score                      0
# Time                       0
# Review_Summary             0
# Review_Text                0
# dtype: int64

# %% [markdown]
# - **We don't have null values in our dataset**

# %%
# Lets check duplicate data
dup = df[df.duplicated(subset=['User_Id','profile_name','Time','Review_Text'],keep=False)]
dup.shape
# Out:
# (964, 9)

# %% [markdown]
# - **We have duplicate data present in our dataset so we will keep only first review and will  delete rest entry**

# %%
# drop duplicate entries
df = df.drop_duplicates(subset=['User_Id','profile_name','Time','Review_Text'],keep='first',inplace=False)
df.shape
# Out:
# (9515, 9)

# %%
# check value count of score
df['Score'].unique()
# Out:
# array([5, 1, 4, 2, 3], dtype=int64)

# %%
plt.figure(figsize=(10,7))
sns.countplot(df.Score)
plt.xlabel('Rating Score',fontdict = {'size' : 18})
plt.show()

# %% [markdown]
# - We have total five unique values of rating among them 5 rating has highest count

# %% [markdown]
# - Here we need to make certain changes in our score.
#     - We have five unique values of score, in which score 1 & 2 is lowest score which is also considerd as negative review.
#     - The Score 4 & 5 is considerd as positive review.
#     - so, here we will encode positive score as '1' and negative socre as '0'
#     - score 3 is considerd as neutral.

# %% [markdown]
# ### Now we will create our target variable from score

# %%
# changing the datatype of score
df.Score = pd.to_numeric(df.Score, errors='coerce')

# %%
# we will filter only those score with rating greater than 3(positive) and less than 3(negative)
def rating(x):
    if(x < 3):
        return 0

    else:
        return 1

# %%
df['rating'] = df['Score'].apply(rating)
df.rating.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.head()
# Out:
#     Product_Id          User_Id                      profile_name  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#    Helpfulness_Numerator  Helpfulness_Denominator  Score        Time  \
# 0                      1                        1      5  1303862400
# 1                      0                        0      1  1346976000
# 2                      1                        1      4  1219017600
# 3                      3                        3      2  1307923200
# 4                      0                        0      5  1350777600
#
#            Review_Summary                                        Review_Text  \
# 0   Good Quality Dog Food   I have bought several of the Vitality canned ...
# 1       Not as Advertised   Product arrived labeled as Jumbo Salted Peanu...
# 2   "Delight" says it all   This is a confection that has been around a f...
# 3          Cough Medicine   If you are looking for the secret ingredient ...
# 4             Great taffy   Great taffy at a great price.  There was a wi...
#
#    rating
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1

# %%
plt.figure(figsize=(8,6))
sns.countplot(df['rating'], palette='Accent' )
plt.title('Target Variable count',fontdict = {'size' : 20})
plt.xlabel('rating',fontdict = {'size' : 15})
plt.show()

# %% [markdown]
# - **We can clearly see that, we have imbalenced dataset for classification.**

# %%
#df[df['Helpfulness_Numerator'] > df['Helpfulness_Denominator']]

# %% [markdown]
# ### Find popular words in positive and negative score

# %%
positive_score = df[df.rating == 1]['Review_Text']

# %%
positive_score
# Out:
# 0        I have bought several of the Vitality canned ...
# 2        This is a confection that has been around a f...
# 4        Great taffy at a great price.  There was a wi...
# 5        I got a wild hair for taffy and ordered this ...
# 6        This saltwater taffy had great flavors and wa...
#                               ...
# 9994     I switched from Similac Advanced to Organic w...
# 9996     Like the bad reviews say, the organic formula...
# 9997     I wanted to solely breastfeed but was unable ...
# 9998     i love the fact that i can get this delieved ...
# 9999     We have a 7 week old... He had gas and consti...
# Name: Review_Text, Length: 8082, dtype: object

# %%
negative_score = df[df.rating == 0]['Review_Text']
negative_score
# Out:
# 1        Product arrived labeled as Jumbo Salted Peanu...
# 3        If you are looking for the secret ingredient ...
# 12       My cats have been happily eating Felidae Plat...
# 16       I love eating them and they are good for watc...
# 26       The candy is just red , No flavor . Just  pla...
#                               ...
# 9976     This was the first time I tried purchasing a ...
# 9977     I was surprised by the number of 5 star revie...
# 9985     You think you're doing something good for you...
# 9986     2.0 out of 5 stars Read this article first, A...
# 9995     we switched from the advance similac to the o...
# Name: Review_Text, Length: 1433, dtype: object

# %%
p_text= ' '.join(positive_score)

p_clean = ' '.join([word for word in p_text.split()
                       if 'br' not in word])

p_wordcloud = WordCloud(stopwords = stopwords.words('english'),
                          background_color='black',
                          width=1500,
                          height=600).generate(p_clean)

# %%
# plot wordcount of positive text
plt.figure(1,figsize=(28,22))
plt.imshow(p_wordcloud)
plt.show()

# %%
n_text= ' '.join(negative_score)
n_clean = ' '.join([word for word in n_text.split()
                       if 'br' not in word])
n_wordcloud = WordCloud(stopwords = stopwords.words('english'),
                          background_color='black',
                          width=1500,
                          height=600).generate(n_clean)

# %%
# plot wordcount of positive text
plt.figure(1,figsize=(28,22))
plt.imshow(n_wordcloud)
plt.show()

# %%
df.Helpfulness_Numerator = df.Helpfulness_Numerator.astype(int)

# %%
df.Helpfulness_Denominator = df.Helpfulness_Denominator.astype(int)

# %%
Helpfulness = df.Helpfulness_Numerator/df.Helpfulness_Denominator

# %%
Helpfulness = Helpfulness * 100

# %% [markdown]
# - Now we need to create a dataframe for helpfulness.
# - we should divide the helpfulness into different categories
#     - Helpful review : more than 75 % of voters
#     - non helpful review : less than 25 % of voters
#     - Intermediate review : on between 25 % to 75 %
#     - no review : non voters

# %%
# creating dataframe of helpful
df_Helpfulness = pd.DataFrame(Helpfulness)

# %%
# creating column in df helpful
df_Helpfulness.columns = ['Helpfulness']

# %%
# create function for different helpfulness
def helpfulness_category(x):
    if x > 75:
        return 'Helpful'
    elif x < 25:
        return 'Nonhelpful'
    elif x >= 25 and x <= 75:
        return 'Intermediate'
    else:
        return 'No review'

# %%
df_Helpfulness['category'] = df_Helpfulness['Helpfulness'].apply(helpfulness_category)

# %%
df_Helpfulness
# Out:
#       Helpfulness      category
# 0      100.000000       Helpful
# 1             NaN     No review
# 2      100.000000       Helpful
# 3      100.000000       Helpful
# 4             NaN     No review
# ...           ...           ...
# 9995    66.666667  Intermediate
# 9996    66.666667  Intermediate
# 9997          NaN     No review
# 9998    50.000000  Intermediate
# 9999     0.000000    Nonhelpful
#
# [9515 rows x 2 columns]

# %%
df_Helpfulness['category'].value_counts()
# Out:
# No review       4572
# Helpful         3364
# Intermediate     909
# Nonhelpful       670
# Name: category, dtype: int64

# %% [markdown]
# ### Distribution of Helpfulness

# %%
# plot distribution of helpfulness
height = df_Helpfulness.category.value_counts(normalize=True).values*100
bars = df_Helpfulness.category.value_counts(normalize=True).index
x_pos = np.arange(len(bars))
plt.bar(x_pos, height, color=['red', 'green', 'indigo', 'violet'])
plt.xticks(x_pos, bars)
plt.show()

# %%
# lets make a copy of dataframe
df1 = df.copy()

# %%
# concat helpfullness dataframe and df1
df1 = pd.concat([df1, df_Helpfulness], axis=1)
df1.head()
# Out:
#     Product_Id          User_Id                      profile_name  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#    Helpfulness_Numerator  Helpfulness_Denominator  Score        Time  \
# 0                      1                        1      5  1303862400
# 1                      0                        0      1  1346976000
# 2                      1                        1      4  1219017600
# 3                      3                        3      2  1307923200
# 4                      0                        0      5  1350777600
#
#            Review_Summary                                        Review_Text  \
# 0   Good Quality Dog Food   I have bought several of the Vitality canned ...
# 1       Not as Advertised   Product arrived labeled as Jumbo Salted Peanu...
# 2   "Delight" says it all   This is a confection that has been around a f...
# 3          Cough Medicine   If you are looking for the secret ingredient ...
# 4             Great taffy   Great taffy at a great price.  There was a wi...
#
#    rating  Helpfulness   category
# 0       1        100.0    Helpful
# 1       0          NaN  No review
# 2       1        100.0    Helpful
# 3       0        100.0    Helpful
# 4       1          NaN  No review

# %%
# lets remove no review from df1
df1 = df1[df1.category != 'No review']
df1.shape
# Out:
# (4943, 12)

# %% [markdown]
# ### How does rating affect on Helpfulness?

# %%
sns.countplot(x='rating', hue='category', order=[1, 0], 
              hue_order=['Helpful', 'Intermediate', 'Nonhelpful'], data=df1)
plt.xlabel('Rating')
plt.show()

# %% [markdown]
# **Here we can see that, positive rating review found more helpful**

# %% [markdown]
# ### Word count

# %%
df2 = df_copy.copy()

# %%
# wordcount function
def word_count(x):
    rex = len(re.findall(r'\w+',x))
    return rex

# %%
df2['Wordcount'] = df2.Review_Text.apply(word_count)

# %%
df2.head()
# Out:
#     Product_Id          User_Id                      profile_name  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#    Helpfulness_Numerator  Helpfulness_Denominator  Score        Time  \
# 0                      1                        1      5  1303862400
# 1                      0                        0      1  1346976000
# 2                      1                        1      4  1219017600
# 3                      3                        3      2  1307923200
# 4                      0                        0      5  1350777600
#
#            Review_Summary                                        Review_Text  \
# 0   Good Quality Dog Food   I have bought several of the Vitality canned ...
# 1       Not as Advertised   Product arrived labeled as Jumbo Salted Peanu...
# 2   "Delight" says it all   This is a confection that has been around a f...
# 3          Cough Medicine   If you are looking for the secret ingredient ...
# 4             Great taffy   Great taffy at a great price.  There was a wi...
#
#    Wordcount
# 0         48
# 1         32
# 2         93
# 3         41
# 4         27

# %%
# plotting word count v/s score 
plt.figure(figsize=(10,6))
palette = ['plum', 'g', 'orange', 'cyan', 'r']
sns.boxplot(x = 'Score',y = 'Wordcount',data = df2,showfliers=False, palette = palette)
plt.xlabel("Score", fontdict={'size':18})
plt.ylabel("Wordcount", fontdict={'size':18})
plt.show()

# %% [markdown]
# **5-star reviews has the lowest median word count.**

# %%
df1['Wordcount'] = df1.Review_Text.apply(word_count)

# %%
df1.head()
# Out:
#      Product_Id          User_Id                      profile_name  \
# 0    B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 2    B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3    B000UA0QIQ   A395BORC6FGVXV                              Karl
# 8    B000E7L2R4   A1MZYO9TZK0BBI                          R. James
# 10   B0001PB9FE   A3HDKO7OW0QNK4                      Canadian Fan
#
#     Helpfulness_Numerator  Helpfulness_Denominator  Score        Time  \
# 0                       1                        1      5  1303862400
# 2                       1                        1      4  1219017600
# 3                       3                        3      2  1307923200
# 8                       1                        1      5  1322006400
# 10                      1                        1      5  1107820800
#
#                       Review_Summary  \
# 0              Good Quality Dog Food
# 2              "Delight" says it all
# 3                     Cough Medicine
# 8                         Yay Barley
# 10   The Best Hot Sauce in the World
#
#                                           Review_Text  rating  Helpfulness  \
# 0    I have bought several of the Vitality canned ...       1        100.0
# 2    This is a confection that has been around a f...       1        100.0
# 3    If you are looking for the secret ingredient ...       0        100.0
# 8    Right now I'm mostly just sprouting this so m...       1        100.0
# 10   I don't know if it's the cactus or the tequil...       1        100.0
#
#    category  Wordcount
# 0   Helpful         48
# 2   Helpful         93
# 3   Helpful         41
# 8   Helpful         27
# 10  Helpful        154

# %%
# plotting wordcount v/s helpfulness
plt.figure(figsize=(10,6))
sns.violinplot(x = 'category',y = 'Wordcount',data = df1,inner='quartile')
plt.ylim(0,300)
plt.xlabel("Category", fontdict={'size':18})
plt.ylabel("Wordcount", fontdict={'size':18})
plt.show()

# %% [markdown]
# **wordcount of all categories are almost same but helpful review has more wordcount than others.**

# %% [markdown]
# ### Things we can conclude from  analysis:
#
# - Most probably reviewrs give positive review.
#
# - Positive reviews seems shorter than others.
#
# - Longer reviews are more helpful for people.
#
# - so we can say that,shorterand positive reviews found more helpful.

# %% [markdown]
# <p style = "font-size:30px; color: #007580  "><strong> Model building</strong></p>

# %%
# initialize feature and target
X = df.loc[: , ['Review_Text']]
y = df.loc[: , 'rating']

# %%
# remove stopwords
stop = set(stopwords.words('english'))
punctuation = list(string.punctuation)
stop.update(punctuation)

# %%
# text cleaning
snow = stem.SnowballStemmer('english')
def text_cleaning(sentence):
    sentence = sentence.lower()
    cleanr = re.compile('<.*?>')
    sentence = re.sub(cleanr, ' ', sentence) #removed html tag
    words = [snow.stem(word) for word in sentence.split() if word not in stop]
    return ' '.join(words)

# %% [markdown]
# https://www.geeksforgeeks.org/removing-stop-words-nltk-python/

# %%
# make seperate column for clean text
X['cleaned_text'] = X['Review_Text'].apply(text_cleaning)
X.head()
# Out:
#                                          Review_Text  \
# 0   I have bought several of the Vitality canned ...
# 1   Product arrived labeled as Jumbo Salted Peanu...
# 2   This is a confection that has been around a f...
# 3   If you are looking for the secret ingredient ...
# 4   Great taffy at a great price.  There was a wi...
#
#                                         cleaned_text
# 0  bought sever vital can dog food product found ...
# 1  product arriv label jumbo salt peanuts...th pe...
# 2  confect around centuries. light, pillowi citru...
# 3  look secret ingredi robitussin believ found it...
# 4  great taffi great price. wide assort yummi taf...

# %%
# %%time
tfidf = TfidfVectorizer(max_features = 5000)
tf_data = tfidf.fit_transform(X['cleaned_text'])
# Out:
# Wall time: 282 ms

# %% [markdown]
# https://www.geeksforgeeks.org/understanding-tf-idf-term-frequency-inverse-document-frequency/

# %%
# train test split
X_train  , X_test , y_train , y_test = train_test_split(tf_data , y , test_size = 0.2 , stratify = y)

# %%
# balancing target variable
sm = SMOTE(random_state = 2)
X_train1, y_train2 = sm.fit_resample(X_train, y_train)

# %% [markdown]
# https://www.geeksforgeeks.org/ml-handling-imbalanced-data-with-smote-and-near-miss-algorithm-in-python/

# %% [markdown]
# ### Logistic regression

# %%
model = LogisticRegression()
lr = LogisticRegression()
lr.fit(X_train1, y_train2) 
pred1 = lr.predict(X_test)  
# print classification report
print(classification_report(y_test, pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.67      0.60       287
#            1       0.94      0.90      0.92      1616
#
#     accuracy                           0.86      1903
#    macro avg       0.74      0.79      0.76      1903
# weighted avg       0.88      0.86      0.87      1903

# %%
a=input()
#vectors
#positive   negative---

# %% [markdown]
# ### SVC

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train1 , y_train2)
pred2 = svc.predict(X_test)
accuracy_score(y_test , pred2)
print(classification_report(y_test, pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.23      0.36       287
#            1       0.88      0.99      0.93      1616
#
#     accuracy                           0.88      1903
#    macro avg       0.87      0.61      0.65      1903
# weighted avg       0.88      0.88      0.85      1903

# %% [markdown]
# ### Decision Treee classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train1 , y_train2)
pred3 = dt.predict(X_test)
accuracy_score(y_test , pred3)
print(classification_report(y_test, pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.30      0.39      0.34       287
#            1       0.89      0.84      0.86      1616
#
#     accuracy                           0.77      1903
#    macro avg       0.59      0.61      0.60      1903
# weighted avg       0.80      0.77      0.78      1903

# %% [markdown]
# ### Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train1 , y_train2)
pred4 = rf.predict(X_test)
accuracy_score(y_test , pred4)
print(classification_report(y_test, pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.28      0.36       287
#            1       0.88      0.95      0.92      1616
#
#     accuracy                           0.85      1903
#    macro avg       0.70      0.62      0.64      1903
# weighted avg       0.83      0.85      0.83      1903

# %% [markdown]
# ### XG Boost classifier

# %%
import xgboost as xgb
xgb = xgb.XGBClassifier()
xgb.fit(X_train1 , y_train2)
pred5 = xgb.predict(X_test)
accuracy_score(y_test , pred5)
print(classification_report(y_test, pred5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.34      0.39       287
#            1       0.89      0.93      0.91      1616
#
#     accuracy                           0.84      1903
#    macro avg       0.68      0.64      0.65      1903
# weighted avg       0.83      0.84      0.83      1903

# %% [raw]
# pred = lr.predict(X_test[1])
# pred

# %% [markdown]
# <p style = "font-size:30px; color: #6610f2 "><strong> Conclusion</strong></p>

# %% [markdown]
# - We have imbalace dataset so, to balance them we use smote technique.
# - We found that reviewer mostly give positive review.
# - riview which are shorter, positive are found more helpful to people.
# - Here we use five model for prediction, among all logistic regression give better accuracy .
